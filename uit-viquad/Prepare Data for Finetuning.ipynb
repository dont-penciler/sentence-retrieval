# %% [markdown]
# # Header

# %% [markdown]
# #### We consider three different types of negatives:
# (1) Random: any random passage from the corpus; <br>
# (2) BM25: top passages returned by BM25 which don’t contain
# the answer but match most question tokens; <br>
# (3) Gold: positive passages paired with other questions which appear in the training set. <br>
#
# Regression Objective Function. The cosinesimilarity between the two sentence embeddings
# u and v is computed. We use meansquared-error loss as the objective function.

# %% [markdown]
# #### 1. How can I construct samples? In DPR they generate negative samples by just sample pairs of format: (one question, answer of another question). <br>
# But in my case, with a given context (including several sentences), two questions can map to a similar sentence. <br>
# E.g. If the 2 questions are "Ai huong dan NTD?" va "LHL huong dan ai?" then answer_sentence is the same: "Anh LHL huong dan NTD." <br>
# ==> Solution:  Pair one question with all (or selected) other sentences of the context that do not contain the answer. <br>
#
# #### 2. Which loss function should I use? <br>
# ==> Solution: Just use the CosineSimilarityLoss is enough. It's an instance of ContrastiveLoss. <br>
# It computes the vectors u = model(input_text[0]) and v = model(input_text[1]) and measures the cosine-similarity between the two. By default, it minimizes the following loss: ||input_label - cos_score_transformation(cosine_sim(u,v))||_2. <br>
# Here this loss expects as input two texts and a label of either 0 or 1. If the label == 1, then the distance between the two embeddings is reduced. If the label == 0, then the distance between the embeddings is increased. <br>

# %%
# %cd "/content/drive/MyDrive/vdt_dsai/dataset"
# Out:
# /content/drive/MyDrive/vdt_dsai/dataset

# %%
import json 
with open("train_file.json") as f:
    train_file =  json.load(f)
with open("val_file.json") as f:
    val_file =  json.load(f)
with open("test_file.json") as f:
    test_file =  json.load(f)

# %%
def find_sentence(corpus, start_answer):
    '''
    Find sentence contains answer
    * corpus: list sentences of context
    * start_answer: the begin position of answer in context
    '''
    start, end = 0, -1
    sent_idx = -1
    for i in range(len(corpus)):
        sentence = corpus[i]
        start = end + 1
        end = start+len(sentence)
        if start<=start_answer<end:
            sent_idx = i
            break
        elif start_answer == end:
            sent_idx = i + 1
            break 
    return sent_idx

# %%
# !pip install rank_bm25
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rank_bm25) (1.21.6)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %%
from rank_bm25 import BM25Okapi
from rank_bm25 import BM25Plus
from copy import deepcopy
from sklearn.feature_extraction.text import TfidfVectorizer
import sklearn
import torch 

def get_topk_sentences_bm25(data, top_k):
    """
    Using sklearn TFIDF to get top k most relevant sentences for each question
    """
    copied_data = deepcopy(data)
    for topic in copied_data['data']:
        for paragraph in topic['paragraphs']:
            context = paragraph['context']
            vectorizer = TfidfVectorizer()
            tokenizer = vectorizer.build_tokenizer()
            tokenized_context = [tokenizer(sentence.lower()) for sentence in context]
            
            # learn statistic of the context sentences.
            bm25 = BM25Plus(tokenized_context)
            for qa in paragraph['qas']:
                question = qa['question']
                query = tokenizer(question)

                # compute scores of each sentence in the context.
                scores = bm25.get_scores(query)
                k = min(top_k, len(context))
                top_results = torch.topk(torch.tensor(scores.reshape(-1)), k=k)
                qa['candidate_indices'] = top_results[1].tolist()
    return copied_data

# %%
# !pip install underthesea
# !pip install pyvi

# %%
import numpy as np
from pyvi.ViTokenizer import tokenize
from underthesea import sent_tokenize


def get_sentence_pairs_bm25(data, topk):
    """
    From data consisting of (context, qas), construct sentence pairs in the format:
    Positive pair: (one question, sentence containing the answer to that question, lable=1.0)
    Negative pair: (one question, sentences in the context of the question that does not contains the answer, label=0.0)
    """
    sentence_pairs = []

    for topic in data['data']:
        for paragraph in topic['paragraphs']:
            context = paragraph['context']
            for qa in paragraph['qas']:
                if len(qa['answers']) > 0:

                    # If the answer is from multiple sentences then discard this qa
                    if len(sent_tokenize(qa['answers'][0]['text'])) > 1:
                        continue 
                    question = tokenize(qa['question'])

                    # Get the answer sentence. Consider it as positive sentence.
                    answer_start = qa['answers'][0]['answer_start']
                    ans_sent_idx = find_sentence(context, answer_start)
                    pos_sent = tokenize(context[ans_sent_idx])
                    sentence_pairs.append((question, pos_sent, 1.0))

                    # Get all the sentences that are not the answer sentence.
                    neg_sent_idxs = np.delete(np.arange(len(context)), ans_sent_idx)

                    candidate_indices = np.array(qa['candidate_indices'])
                    neg_sent_idxs = candidate_indices[candidate_indices != ans_sent_idx]
                    topk_neg_sent_idxs = neg_sent_idxs[:topk]
                    for neg_idx in topk_neg_sent_idxs:
                        neg_sent = tokenize(context[neg_idx])
                        sentence_pairs.append((question, neg_sent, 0.0))
    
    return sentence_pairs

# %% [markdown]
# # Sample top 3 negative sentences BM25

# %%
train_file_bm25 = get_topk_sentences_bm25(train_file, 10)
train_pairs = get_sentence_pairs_bm25(train_file_bm25, 3)
train_object = json.dumps(train_pairs, ensure_ascii=False)
with open("train_pairs_bm25.json", "w") as write_file:
    write_file.write(train_object)

val_file_bm25 = get_topk_sentences_bm25(val_file, 10)
val_pairs = get_sentence_pairs_bm25(val_file_bm25, 3)
val_object = json.dumps(val_pairs, ensure_ascii=False)
with open("val_pairs_bm25.json", "w") as write_file:
    write_file.write(val_object)

test_file_bm25 = get_topk_sentences_bm25(test_file, 10)
test_pairs = get_sentence_pairs_bm25(test_file_bm25, 3)
test_object = json.dumps(test_pairs, ensure_ascii=False)
with open("test_pairs_bm25.json", "w") as write_file:
    write_file.write(test_object)

# %%
print("Number of pairs in train pairs:", len(train_pairs))
print("Number of pairs in val pairs:", len(val_pairs))
print("Number of pairs in test pairs:", len(test_pairs))
# Out:
# Number of pairs in train pairs: 58967
# Number of pairs in val pairs: 7202
# Number of pairs in test pairs: 6367

# %%
with open("train_pairs_bm25.json") as f:
    train_pairs = json.load(f)
train_pairs[:100]
# Out:
# [['Karl_Heinrich Marx trong phiên_âm tiếng Việt_đọc như thế_nào ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Karl_Heinrich Marx trong phiên_âm tiếng Việt_đọc như thế_nào ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Các Mác sinh vào năm nào ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác sinh vào năm nào ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Các Mác sinh ra tại đâu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác sinh ra tại đâu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Marx là học_giả ảnh_hưởng nhất thế_giới do nơi nào nghiên_cứu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   1.0],
#  ['Marx là học_giả ảnh_hưởng nhất thế_giới do nơi nào nghiên_cứu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   0.0],
#  ['Các Mác qua_đời năm bao_nhiêu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác qua_đời năm bao_nhiêu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Căn_cứ nào để kết_luận rằng Marx là học_giả có ảnh_hưởng nhất thế_giới ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   1.0],
#  ['Căn_cứ nào để kết_luận rằng Marx là học_giả có ảnh_hưởng nhất thế_giới ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   1.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Marx được nhắc đến với nhiều chủ_đề khác nhau , nhưng ông nổi_tiếng nhất với những phân_tích lịch_sử dựa trên thuật_ngữ đấu_tranh giai_cấp , được tổng_kết lại trong những lời mở_đầu cho Tuyên_ngôn Đảng Cộng_sản ( Das Manifest der Kommunistischen_Partei ) : " Lịch_sử của tất_cả các xã_hội từ trước đến nay là lịch_sử của đấu_tranh giai_cấp . "',
#   1.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Ông cũng là người sáng_lập Chủ_nghĩa Xã_hội Khoa_học cùng Friedrich_Engels .',
#   1.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   1.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Marx được nhắc đến với nhiều chủ_đề khác nhau , nhưng ông nổi_tiếng nhất với những phân_tích lịch_sử dựa trên thuật_ngữ đấu_tranh giai_cấp , được tổng_kết lại trong những lời mở_đầu cho Tuyên_ngôn Đảng Cộng_sản ( Das Manifest der Kommunistischen_Partei ) : " Lịch_sử của tất_cả các xã_hội từ trước đến nay là lịch_sử của đấu_tranh giai_cấp . "',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   1.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   1.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   1.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   1.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   1.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   1.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   1.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   1.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   1.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Trước khi con_trai mình ra_đời , Herschel đã cải đạo sang Lutheran để thoát khỏi các sức_ép của chủ_nghĩa bài Do_Thái .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   1.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Ông ngoại của Marx là một giáo_sĩ rabi Hà_Lan , trong khi họ nội của ông đã có nhiều người_làm rabi ở Trier kể từ năm 1772 .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Tuổi_thơ của Marx được tiếp_xúc với nhiều học_giả , họa_sĩ thường_xuyên lui_tới gia_đình ông .',
#   1.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   1.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Ông cũng học tốt môn Toán .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   1.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Ông ngoại của Marx là một giáo_sĩ rabi Hà_Lan , trong khi họ nội của ông đã có nhiều người_làm rabi ở Trier kể từ năm 1772 .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   1.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Ông cũng học tốt môn Toán .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Tuổi_thơ của Marx được tiếp_xúc với nhiều học_giả , họa_sĩ thường_xuyên lui_tới gia_đình ông .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   1.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   1.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   1.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   1.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   0.0]]

# %% [markdown]
# # Sample top 5 negative sentences BM25

# %%
train_file_bm25 = get_topk_sentences_bm25(train_file, 10)
train_pairs = get_sentence_pairs_bm25(train_file_bm25, 5)
train_object = json.dumps(train_pairs, ensure_ascii=False)
with open("train_pairs_top5.json", "w") as write_file:
    write_file.write(train_object)

val_file_bm25 = get_topk_sentences_bm25(val_file, 10)
val_pairs = get_sentence_pairs_bm25(val_file_bm25, 5)
val_object = json.dumps(val_pairs, ensure_ascii=False)
with open("val_pairs_top5.json", "w") as write_file:
    write_file.write(val_object)

test_file_bm25 = get_topk_sentences_bm25(test_file, 10)
test_pairs = get_sentence_pairs_bm25(test_file_bm25, 5)
test_object = json.dumps(test_pairs, ensure_ascii=False)
with open("test_pairs_top5.json", "w") as write_file:
    write_file.write(test_object)

# %%
print("Number of pairs in train pairs:", len(train_pairs))
print("Number of pairs in val pairs:", len(val_pairs))
print("Number of pairs in test pairs:", len(test_pairs))
# Out:
# Number of pairs in train pairs: 75199
# Number of pairs in val pairs: 9352
# Number of pairs in test pairs: 7974

# %%
with open("train_pairs_top5.json") as f:
    train_pairs = json.load(f)
train_pairs[:100]
# Out:
# [['Karl_Heinrich Marx trong phiên_âm tiếng Việt_đọc như thế_nào ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Karl_Heinrich Marx trong phiên_âm tiếng Việt_đọc như thế_nào ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Các Mác sinh vào năm nào ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác sinh vào năm nào ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Các Mác sinh ra tại đâu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác sinh ra tại đâu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Marx là học_giả ảnh_hưởng nhất thế_giới do nơi nào nghiên_cứu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   1.0],
#  ['Marx là học_giả ảnh_hưởng nhất thế_giới do nơi nào nghiên_cứu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   0.0],
#  ['Các Mác qua_đời năm bao_nhiêu ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   1.0],
#  ['Các Mác qua_đời năm bao_nhiêu ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   0.0],
#  ['Căn_cứ nào để kết_luận rằng Marx là học_giả có ảnh_hưởng nhất thế_giới ?',
#   'Theo kết_quả nghiên_cứu từ Đại_học Indiana tại Bloomington , Marx là học_giả có ảnh_hưởng nhất thế_giới dựa trên số_lượng nghiên_cứu và độ phổ_biến của các nghiên_cứu .',
#   1.0],
#  ['Căn_cứ nào để kết_luận rằng Marx là học_giả có ảnh_hưởng nhất thế_giới ?',
#   'Karl_Heinrich_Marx ( phát_âm tiếng Đức : [ kaːɐ ̯ l ˈhaɪnʀɪç ˈmaːɐ ̯ ks ] , thường được phiên_âm là Các Mác trong các tài_liệu tiếng Việt hoặc Hán Việt là Mã_Khắc_Tư ; sinh 5 tháng 5 năm 1818 tại Trier , Vương_quốc Phổ – mất 14 tháng 3 năm 1883 tại Luân_Đôn , Vương_quốc Anh ) là nhà tư_tưởng người Đức gốc Do thái , và cũng là nhà kinh_tế , nhà lãnh_đạo cách_mạng của Hiệp_hội Người lao_động Quốc_tế .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   1.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Các Mác hoạt_động cách_mạng và triết_học trong thời_gian nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Marx được nhắc đến với nhiều chủ_đề khác nhau , nhưng ông nổi_tiếng nhất với những phân_tích lịch_sử dựa trên thuật_ngữ đấu_tranh giai_cấp , được tổng_kết lại trong những lời mở_đầu cho Tuyên_ngôn Đảng Cộng_sản ( Das Manifest der Kommunistischen_Partei ) : " Lịch_sử của tất_cả các xã_hội từ trước đến nay là lịch_sử của đấu_tranh giai_cấp . "',
#   1.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx nổi_tiếng nhất với nghiên_cứu nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Ông cũng là người sáng_lập Chủ_nghĩa Xã_hội Khoa_học cùng Friedrich_Engels .',
#   1.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Ai là người cùng Marx sáng_lập Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   1.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Marx được nhắc đến với nhiều chủ_đề khác nhau , nhưng ông nổi_tiếng nhất với những phân_tích lịch_sử dựa trên thuật_ngữ đấu_tranh giai_cấp , được tổng_kết lại trong những lời mở_đầu cho Tuyên_ngôn Đảng Cộng_sản ( Das Manifest der Kommunistischen_Partei ) : " Lịch_sử của tất_cả các xã_hội từ trước đến nay là lịch_sử của đấu_tranh giai_cấp . "',
#   0.0],
#  ['" Tuyên_ngôn của Đảng Cộng_sản " được Marx viết vào thời_gian nào ?',
#   'Những hoạt_động cách_mạng và triết_học của ông diễn ra trong thập_niên 1840 - giữa lúc chủ_nghĩa tư_bản đang trong thời_kỳ phát_triển và giai_cấp vô_sản công_nghiệp ra_đời và có những hoạt_động cách_mạng chống_chế_độ tư_bản .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   1.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   0.0],
#  ['Những ý_tưởng cải_cách của Marx được mọi người đón_nhận như thế_nào ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Tư_tưởng của ông là học_thuyết kế_thừa các hệ tư_tưởng được thành_lập trong thế_kỷ XIX , bao_gồm triết_học cổ_điển Đức , học_thuyết về kinh_tế chính_trị tư_sản cổ_điển Anh hay chủ_nghĩa xã_hội_học Pháp .',
#   1.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Với Tuyên_ngôn này , chủ_nghĩa xã_hội khoa_học được định_hình kế_thừa từ chủ_nghĩa xã_hội không_tưởng .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Những ý_tưởng cải_cách của Marx trong Tuyên_ngôn của Đảng Cộng_sản đã được áp_dụng tại hầu_hết các quốc_gia trên thế_giới , góp_phần kiến_tạo nên xã_hội hiện_đại .',
#   0.0],
#  ['Marx đã kế_thừa những hệ tư_tưởng nào để xây dưng nên Chủ_nghĩa Xã_hội Khoa_học ?',
#   'Karl_Marx và người bạn thân của ông , Friedrich_Engels , đã viết " Tuyên_ngôn của Đảng Cộng_sản " vào năm 1848 , nói cách khác là hai ông đã lên_án những bất_công trong chế_độ tư_bản đồng_thời đưa ra các biện_pháp cải_cách kinh_tế - xã_hội để hướng xã_hội công_nghiệp phương Tây đến chủ_nghĩa cộng_sản .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   1.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   0.0],
#  ['Marx có nhận_xét gì về cách hiểu của Hegel về sự phát_triển của loài_người ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   1.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Quan_điểm của Marx về sự phát_triển của loài_người như thế_nào ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   1.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Con_người có_thể cải_tạo tự_nhiên thông_qua việc gì ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   1.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Marx cho rằng nhân_loại sẽ phát_triển như thế_nào ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Người_ta nói tư_tưởng của Marx là chủ_nghĩa duy_vật biện_chứng , lịch_sử , hay khoa_học .',
#   1.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Ông cũng cho rằng , con_người có_thể cải_tạo tự_nhiên qua việc sản_xuất .',
#   0.0],
#  ['Người_ta nhận_xét gì về chủ_nghĩa của Marx ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Tuy_nhiên , mặt_khác ông cho rằng vật_chất mới đóng vai_trò chính_yếu trong quá_trình này , chứ không phải là tinh_thần .',
#   1.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Nhà triết_học người Đức này cho rằng cách hiểu của Hegel về sự phát_triển của lịch_sử loài_người là đúng .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Ông tin rằng xã_hội loài_người có_thể hoạt_động theo lý_tính dựa trên những kiến_thức khoa_học đã tích_lũy được chứ không còn vận_động một_cách tự_phát như trước , loài_người sẽ chuyển từ tự_phát sang tự_giác .',
#   0.0],
#  ['Quan_điểm về sự phát_triển của loài_người của Marx khác với Hegel như thế_nào ?',
#   'Theo ông " Các nhà triết_học đã chỉ giải_thích thế_giới bằng nhiều cách khác nhau , vấn_đề là cải_tạo thế_giới " .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   1.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Trước khi con_trai mình ra_đời , Herschel đã cải đạo sang Lutheran để thoát khỏi các sức_ép của chủ_nghĩa bài Do_Thái .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx sinh ra tại đâu ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   1.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Ông ngoại của Marx là một giáo_sĩ rabi Hà_Lan , trong khi họ nội của ông đã có nhiều người_làm rabi ở Trier kể từ năm 1772 .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   0.0],
#  ['Cha của Karl_Marx là ai ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Tuổi_thơ của Marx được tiếp_xúc với nhiều học_giả , họa_sĩ thường_xuyên lui_tới gia_đình ông .',
#   1.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx có tuổi_thơ như thế_nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   1.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Ông cũng học tốt môn Toán .',
#   0.0],
#  ['Karl_Marx học tại trường trung_học Trier khi nào ?',
#   'Karl_Marx sinh ra trong một gia_đình gốc Do_Thái tại Trier ( còn gọi là Trèves ) thuộc tỉnh Rhénanie của Vương_quốc Phổ .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   1.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Ông ngoại của Marx là một giáo_sĩ rabi Hà_Lan , trong khi họ nội của ông đã có nhiều người_làm rabi ở Trier kể từ năm 1772 .',
#   0.0],
#  ['Cha của Karl_Marx có cuộc_sống như thế_nào ?',
#   'Năm 1830 , Karl_Marx lên 12 tuổi , ông trở_thành học_sinh của trường trung_học Trier .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Là một học_sinh giỏi , ông có sở_trường ở những môn_học cần có tính_chất_độc_lập sáng_tạo .',
#   1.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Ông cũng học tốt môn Toán .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Cha của ông , Heinrich_Marx , hồi nhỏ tên là Herschel_Mordechai , là người đầu_tiên trong dòng_họ tiếp_nhận nền giáo_dục thế_tục , trở_thành một luật_sư và có cuộc_sống trung_lưu khá giàu_có khi gia_đình ông làm_chủ nhiều vườn nho Moselle .',
#   0.0],
#  ['Karl_Marx có sở_trường đối_với các môn_học nào khi ông còn nhỏ ?',
#   'Tuổi_thơ của Marx được tiếp_xúc với nhiều học_giả , họa_sĩ thường_xuyên lui_tới gia_đình ông .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   1.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Marx học tại đâu ở Berlin ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   1.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Marx làm gì khi học đại_học ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   1.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Một trong những tác_phẩm đầu_tiên của Marx là gì ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Marx đạt học_vị Tiến_sĩ năm 1841 với luận_án mang tiêu_đề : " Sự khác_biệt giữa triết_học tự_nhiên của Epicurus với triết_học tự_nhiên của Democritus " .',
#   1.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Những năm tiếp_theo , cha của Marx buộc ông chuyển sang Đại_học Friedrich - Wilhelms ở Berlin .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Trong_suốt giai_đoạn này , ông tiếp_thu triết_học vô_thần của những người Hegel cánh tả ( hay Hegel trẻ ) .',
#   0.0],
#  ['Luận_án giúp Marx đạt học vi tiến_sĩ có tên là gì ?',
#   'Khi đó , Marx viết nhiều thơ và tiểu_luận liên_quan đến cuộc_sống , sử_dụng ngôn_ngữ triết_học nhận được từ người cha thần luận tự_do của mình , chẳng_hạn tác_phẩm " Thượng_đế " .',
#   0.0]]
